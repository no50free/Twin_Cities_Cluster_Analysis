# %%
import pandas as pd
import numpy as np

# %%
# From http://www.mncompass.org/profiles/neighborhoods/minneapolis-saint-paul
df=pd.read_csv('profile_download_file_msp_neighborhoods_2014_2018.csv')
df.head()
# Out:
#             Neighborhood         City  ﻿Total population  \
# 0               Armatage  Minneapolis               5101
# 1           Audubon Park  Minneapolis               4421
# 2               Bancroft  Minneapolis               3609
# 3  Battle Creek-Highwood     St. Paul              58578
# 4        Cedar Riverside  Minneapolis              10065
#
#    Total population - Margin of error Total population - Share  \
# 0                                 346                     100%
# 1                                 287                     100%
# 2                                 274                     100%
# 3                                1314                     100%
# 4                                 866                     100%
#
#   Total population - Share - Margin of error   Male  Male - Margin of error  \
# 0                                      6.80%   2568                     237
# 1                                      6.50%   2205                     214
# 2                                      7.60%   1901                     182
# 3                                      2.20%  29495                     915
# 4                                      8.60%   4961                     717
#
#   Male - Share Male - Share - Margin of error  ...  \
# 0       50.40%                          4.70%  ...
# 1       49.90%                          4.80%  ...
# 2       52.70%                          5.00%  ...
# 3       50.40%                          1.60%  ...
# 4       49.30%                          7.10%  ...
#
#    Workers high school or equivalent  (no college)  \
# 0                                              505
# 1                                              484
# 2                                              386
# 3                                             4761
# 4                                              499
#
#    Workers high school or equivalent (no college) - Share  \
# 0                                             17.40%
# 1                                             17.40%
# 2                                             18.10%
# 3                                             17.70%
# 4                                             17.40%
#
#   Workers some college or associates degree  \
# 0                                       764
# 1                                       683
# 2                                       521
# 3                                      6039
# 4                                       572
#
#   Workers some college or associates degree (Share)  \
# 0                                            26.40%
# 1                                            24.50%
# 2                                            24.40%
# 3                                            22.40%
# 4                                            19.90%
#
#    Workers bachelor's degree or advanced degree  \
# 0                                           992
# 1                                           699
# 2                                           602
# 3                                          6193
# 4                                           467
#
#    Workers bachelor's degree or advanced degree - Share Workers Male  \
# 0                                             34.20%            1410
# 1                                             25.10%            1393
# 2                                             28.20%             991
# 3                                             23.00%           13153
# 4                                             16.30%            1383
#
#   Workers Male - Share  Workers Female  Workers Female - Share
# 0               48.60%            1488                  51.40%
# 1               50.10%            1390                  49.90%
# 2               46.50%            1142                  53.50%
# 3               48.90%           13765                  51.10%
# 4               48.20%            1486                  51.80%
#
# [5 rows x 556 columns]

# %%
df['Neighborhood'][0:10]
# Out:
# 0                 Armatage
# 1             Audubon Park
# 2                 Bancroft
# 3    Battle Creek-Highwood
# 4          Cedar Riverside
# 5         Cedar-Isles-Dean
# 6                  Central
# 7       Como (Minneapolis)
# 8          Como (St. Paul)
# 9                   Cooper
# Name: Neighborhood, dtype: object

# %%
df.columns[0:100]
# Out:
# Index(['Neighborhood', 'City', '﻿Total population',
#        'Total population - Margin of error', 'Total population - Share',
#        'Total population - Share - Margin of error', 'Male',
#        'Male - Margin of error', 'Male - Share',
#        'Male - Share - Margin of error', 'Female', 'Female - Margin of error',
#        'Female - Share', 'Female - Share - Margin of error', 'Under 5 years',
#        'Under 5 years - Margin of error', 'Under 5 years - Share',
#        'Under 5 years - Share - Margin of error', '5-9 years',
#        '5-9 years - Margin of error', '5-9 years - Share',
#        '5-9 years - Share - Margin of error', '10-14 years',
#        '10-14 years - Margin of error', '10-14 years - Share',
#        '10-14 years - Share - Margin of error', '15-17 years',
#        '15-17 years - Margin of error', '15-17 years - Share',
#        '15-17 years - Share - Margin of error', '18-24 years',
#        '18-24 years - Margin of error', '18-24 years - Share',
#        '18-24 years - Share - Margin of error', '25-34 years',
#        '25-34 years - Margin of error', '25-34 years - Share',
#        '25-34 years - Share - Margin of error', '35-44 years',
#        '35-44 years - Margin of error', '35-44 years - Share',
#        '35-44 years - Share - Margin of error', '45-54 years',
#        '45-54 years - Margin of error', '45-54 years - Share',
#        '45-54 years - Share - Margin of error', '55-64 years',
#        '55-64 years - Margin of error', '55-64 years - Share',
#        '55-64 years - Share - Margin of error', '65-74 years',
#        '65-74 years - Margin of error', '65-74 years - Share',
#        '65-74 years - Share - Margin of error', '75-84 years',
#        '75-84 years - Margin of error', '75-84 years - Share',
#        '75-84 years - Share - Margin of error', '85 years and older',
#        '85 years and older - Margin of error', '85 years and older - Share',
#        '85 years and older - Share - Margin of error', 'White',
#        'White - Margin of error', 'White - Share',
#        'White - Share - Margin of error', 'Of Color',
#        'Of Color - Margin of error', 'Of Color - Share',
#        'Of Color - Share - Margin of error', 'Black or African American',
#        'Black or African American - Margin of error',
#        'Black or African American - Share',
#        'Black or African American - Share - Margin of error',
#        'American Indian and Alaska Native',
#        'American Indian and Alaska Native - Margin of error',
#        'American Indian and Alaska Native - Share',
#        'American Indian and Alaska Native - Share - Margin of error',
#        'Asian or Pacific Islander',
#        'Asian or Pacific Islander - Margin of error',
#        'Asian or Pacific Islander - Share',
#        'Asian or Pacific Islander - Share - Margin of error', 'Other race',
#        'Other race - Margin of error', 'Other race - Share',
#        'Other race - Share - Margin of error', 'Two or more races',
#        'Two or more races - Margin of error', 'Two or more races - Share',
#        'Two or more races - Share - Margin of error', 'Hispanic or Latino',
#        'Hispanic or Latino - Margin of error', 'Hispanic or Latino - Share',
#        'Hispanic or Latino - Share - Margin of error', 'Foreign born',
#        'Foreign born - Margin of error', 'Foreign born - Share',
#        'Foreign born - Share - Margin of error',
#        'Population (5 years and older)',
#        'Population (5 years and older) - Margin of error'],
#       dtype='object')

# %%
df.columns[100:200]
# Out:
# Index(['Population (5 years and older) - Share',
#        'Population (5 years and older) - Share - Margin of error',
#        'English only', 'English only - Margin of error',
#        'English only - Share', 'English only - Share - Margin of error',
#        'Language other than English',
#        'Language other than English - Margin of error',
#        'Language other than English - Share',
#        'Language other than English - Share - Margin of error',
#        'Speak English less than "very well"',
#        'Speak English less than "very well" - Margin of error',
#        'Speak English less than "very well" - Share',
#        'Speak English less than "very well" - Share - Margin of error',
#        'Total population for whom disability status is determined',
#        'Total population for whom disability status is determined - Margin of error',
#        'Total population for whom disability status is determined - Share',
#        'Total population for whom disability status is determined - Share - Margin of error',
#        'Population with a disability',
#        'Population with a disability - Margin of error',
#        'Population with a disability - Share',
#        'Population with a disability - Share - Margin of error',
#        'Total population for whom health insurance coverage status is determined',
#        'Total population for whom health insurance coverage status is determined - Margin of error',
#        'Total population for whom health insurance coverage status is determined - Share',
#        'Total population for whom health insurance coverage status is determined - Share - Margin of error',
#        'Population (1 year and older)',
#        'Population (1 year and older) - Margin of error',
#        'Population (1 year and older) - Share',
#        'Population (1 year and older) - Share - Margin of error',
#        'Same residence', 'Same residence - Margin of error',
#        'Same residence - Share', 'Same residence - Share - Margin of error',
#        'Different residence in the U.S.',
#        'Different residence in the U.S. - Margin of error',
#        'Different residence in the U.S. - Share',
#        'Different residence in the U.S. - Share - Margin of error',
#        'Different residence outside the U.S.',
#        'Different residence outside the U.S. - Margin of error',
#        'Different residence outside the U.S. - Share',
#        'Different residence outside the U.S. - Share - Margin of error',
#        'Total housing units', 'Total housing units - Margin of error',
#        'Total housing units - Share',
#        'Total housing units - Share - Margin of error', 'Total households',
#        'Total households - Margin of error', 'Total households - Share',
#        'Total households - Share - Margin of error', 'Family households',
#        'Family households - Margin of error', 'Family households - Share',
#        'Family households - Share - Margin of error',
#        'With children under 18 years',
#        'With children under 18 years - Margin of error',
#        'With children under 18 years - Share',
#        'With children under 18 years - Share - Margin of error',
#        'Married-couple family households',
#        'Married-couple family households - Margin of error',
#        'Married-couple family households - Share',
#        'Married-couple family households - Share - Margin of error',
#        'With children under 18 years.1',
#        'With children under 18 years - Margin of error.1',
#        'With children under 18 years - Share.1',
#        'With children under 18 years - Share - Margin of error.1',
#        'Single-person family households',
#        'Single-person family households - Margin of error',
#        'Single-person family households - Share',
#        'Single-person family households - Share - Margin of error',
#        'With children under 18 years.2',
#        'With children under 18 years - Margin of error.2',
#        'With children under 18 years - Share.2',
#        'With children under 18 years - Share - Margin of error.2',
#        'Nonfamily households', 'Nonfamily households - Margin of error',
#        'Nonfamily households - Share',
#        'Nonfamily households - Share - Margin of error',
#        'Householder living alone',
#        'Householder living alone - Margin of error',
#        'Householder living alone - Share',
#        'Householder living alone - Share - Margin of error',
#        '65 years and over', '65 years and over - Margin of error',
#        '65 years and over - Share',
#        '65 years and over - Share - Margin of error',
#        'Households with one or more children under 18 years',
#        'Households with one or more children under 18 years - Margin of error',
#        'Households with one or more children under 18 years - Share',
#        'Households with one or more children under 18 years - Share - Margin of error',
#        'Households with one or more people 65 years and over',
#        'Households with one or more people 65 years and over - Margin of error',
#        'Households with one or more people 65 years and over - Share',
#        'Households with one or more people 65 years and over - Share - Margin of error',
#        '2000 or later', '2000 or later - Margin of error',
#        '2000 or later - Share', '2000 or later - Share - Margin of error',
#        '1970-1999', '1970-1999 - Margin of error'],
#       dtype='object')

# %%
df.columns[200:300]
# Out:
# Index(['1970-1999 - Share', '1970-1999 - Share - Margin of error', '1940-1969',
#        '1940-1969 - Margin of error', '1940-1969 - Share',
#        '1940-1969 - Share - Margin of error', '1939 or earlier',
#        '1939 or earlier - Margin of error', '1939 or earlier - Share',
#        '1939 or earlier - Share - Margin of error', 'Vacant housing units',
#        'Vacant housing units - Margin of error',
#        'Vacant housing units - Share',
#        'Vacant housing units - Share - Margin of error',
#        'Occupied housing units', 'Occupied housing units - Margin of error',
#        'Occupied housing units - Share',
#        'Occupied housing units - Share - Margin of error',
#        'Average household size', 'Average household size - Margin of error',
#        'Average household size - Share',
#        'Average household size - Share - Margin of error', 'Owner-occupied',
#        'Owner-occupied - Margin of error', 'Owner-occupied - Share',
#        'Owner-occupied - Share - Margin of error', 'Average household size.1',
#        'Average household size - Margin of error.1',
#        'Average household size - Share.1',
#        'Average household size - Share - Margin of error.1', 'Renter-occupied',
#        'Renter-occupied - Margin of error', 'Renter-occupied - Share',
#        'Renter-occupied - Share - Margin of error', 'Average household size.2',
#        'Average household size - Margin of error.2',
#        'Average household size - Share.2',
#        'Average household size - Share - Margin of error.2', 'No vehicles',
#        'No vehicles - Margin of error', 'No vehicles - Share',
#        'No vehicles - Share - Margin of error', '1 vehicle available',
#        '1 vehicle available - Margin of error', '1 vehicle available - Share',
#        '1 vehicle available - Share - Margin of error', '2 vehicles available',
#        '2 vehicles available - Margin of error',
#        '2 vehicles available - Share',
#        '2 vehicles available - Share - Margin of error',
#        '3 or more vehicles available',
#        '3 or more vehicles available - Margin of error',
#        '3 or more vehicles available - Share',
#        '3 or more vehicles available - Share - Margin of error',
#        'Moved in 2010 or later', 'Moved in 2010 or later - Margin of error',
#        'Moved in 2010 or later - Share',
#        'Moved in 2010 or later - Share - Margin of error',
#        'Moved in 2000 to 2009', 'Moved in 2000 to 2009 - Margin of error',
#        'Moved in 2000 to 2009 - Share',
#        'Moved in 2000 to 2009 - Share - Margin of error',
#        'Moved in 1990 to 1999', 'Moved in 1990 to 1999 - Margin of error',
#        'Moved in 1990 to 1999 - Share',
#        'Moved in 1990 to 1999 - Share - Margin of error',
#        'Moved in 1980 to 1989', 'Moved in 1980 to 1989 - Margin of error',
#        'Moved in 1980 to 1989 - Share',
#        'Moved in 1980 to 1989 - Share - Margin of error',
#        'Moved in 1970 to 1979', 'Moved in 1970 to 1979 - Margin of error',
#        'Moved in 1970 to 1979 - Share',
#        'Moved in 1970 to 1979 - Share - Margin of error',
#        'All households for which cost burden is calculated',
#        'All households for which cost burden is calculated - Margin of error',
#        'All households for which cost burden is calculated - Share',
#        'All households for which cost burden is calculated - Share - Margin of error',
#        'Cost-burdened households',
#        'Cost-burdened households - Margin of error',
#        'Cost-burdened households - Share',
#        'Cost-burdened households - Share - Margin of error',
#        'Owner households for which cost burden is calculated',
#        'Owner households for which cost burden is calculated - Margin of error',
#        'Owner households for which cost burden is calculated - Share',
#        'Owner households for which cost burden is calculated - Share - Margin of error',
#        'Cost-burdened owner households',
#        'Cost-burdened owner households - Margin of error',
#        'Cost-burdened owner households - Share',
#        'Cost-burdened owner households - Share - Margin of error',
#        'Renter households for which cost burden is calculated',
#        'Renter households for which cost burden is calculated - Margin of error',
#        'Renter households for which cost burden is calculated - Share',
#        'Renter households for which cost burden is calculated - Share - Margin of error',
#        'Cost-burdened renter households',
#        'Cost-burdened renter households - Margin of error',
#        'Cost-burdened renter households - Share',
#        'Cost-burdened renter households - Share - Margin of error',
#        'Occupied units where residents pay rent',
#        'Occupied units where residents pay rent - Margin of error'],
#       dtype='object')

# %%
df.columns[300:400]
# Out:
# Index(['Occupied units where residents pay rent - Share',
#        'Occupied units where residents pay rent - Share - Margin of error',
#        'Median rent (2008-2012; 2012 dollars)',
#        'Median rent (2008-2012; 2012 dollars) - Margin of error',
#        'Median rent (2008-2012; 2012 dollars) - Share',
#        'Median rent (2008-2012; 2012 dollars) - Share - Margin of error',
#        'Median household income (2008-2012; 2012 dollars)',
#        'Median household income (2008-2012; 2012 dollars) - Margin of error',
#        'Median household income (2008-2012; 2012 dollars) - Share',
#        'Median household income (2008-2012; 2012 dollars) - Share - Margin of error',
#        'Total households.1', 'Total households - Margin of error.1',
#        'Total households - Share.1',
#        'Total households - Share - Margin of error.1', 'Less than $35000',
#        'Less than $35000 - Margin of error', 'Less than $35000 - Share',
#        'Less than $35;000 - Share - Margin of error', '$35000-$49999',
#        '$35000-$49999 - Margin of error', '$35000-$49999 - Share',
#        '$35000-$49999 - Share - Margin of error', '$50000-$74999',
#        '$50000-$74999 - Margin of error', '$50000-$74999 - Share',
#        '$50000-$74999 - Share - Margin of error', '$75000-$99999',
#        '$75000-$99999 - Margin of error', '$75000-$99999 - Share',
#        '$75000-$99999 - Share - Margin of error', '$100000 or more',
#        '$100000 or more - Margin of error', '$100000 or more - Share',
#        '$100000 or more - Share - Margin of error',
#        'All people for whom poverty status is determined',
#        'All people for whom poverty status is determined - Margin of error',
#        'All people for whom poverty status is determined - Share',
#        'All people for whom poverty status is determined - Share - Margin of error',
#        'With income below poverty',
#        'With income below poverty - Margin of error',
#        'With income below poverty - Share',
#        'With income below poverty - Share - Margin of error',
#        'With income 100-149% of poverty',
#        'With income 100-149% of poverty - Margin of error',
#        'With income 100-149% of poverty - Share',
#        'With income 100-149% of poverty - Share - Margin of error',
#        'With income 150-199% of poverty',
#        'With income 150-199% of poverty - Margin of error',
#        'With income 150-199% of poverty - Share',
#        'With income 150-199% of poverty - Share - Margin of error',
#        'With income 200% of poverty or higher',
#        'With income 200% of poverty or higher - Margin of error',
#        'With income 200% of poverty or higher - Share',
#        'With income 200% of poverty or higher - Share - Margin of error',
#        'Total civilian non-institutionalized population; 18-64',
#        'Total civilian non-institutionalized population; 18-64 - Margin of error',
#        'Total civilian non-institutionalized population; 18-64 - Share',
#        'Total civilian non-institutionalized population; 18-64 - Share - Margin of error',
#        'Proportion of working age adults who are employed',
#        'Proportion of working age adults who are employed - Margin of error',
#        'Proportion of working age adults who are employed - Share',
#        'Proportion of working age adults who are employed - Share - Margin of error',
#        'Civilian labor force', 'Civilian labor force - Margin of error',
#        'Civilian labor force - Share',
#        'Civilian labor force - Share - Margin of error', 'Unemployment rate',
#        'Unemployment rate - Margin of error', 'Unemployment rate - Share',
#        'Unemployment rate - Share - Margin of error',
#        'Population (25 years and older)',
#        'Population (25 years and older) - Margin of error',
#        'Population (25 years and older) - Share',
#        'Population (25 years and older) - Share - Margin of error',
#        'Less than high school', 'Less than high school - Margin of error',
#        'Less than high school - Share',
#        'Less than high school - Share - Margin of error',
#        'High school diploma or GED',
#        'High school diploma or GED - Margin of error',
#        'High school diploma or GED - Share',
#        'High school diploma or GED - Share - Margin of error',
#        'Some college or associate’s degree',
#        'Some college or associate’s degree - Margin of error',
#        'Some college or associate’s degree - Share',
#        'Some college or associate’s degree - Share - Margin of error',
#        'Bachelor's degree', 'Bachelor's degree - Margin of error',
#        'Bachelor's degree - Share',
#        'Bachelor's degree - Share - Margin of error',
#        'Graduate or professional degree',
#        'Graduate or professional degree - Margin of error',
#        'Graduate or professional degree - Share',
#        'Graduate or professional degree - Share - Margin of error',
#        'High school graduate or higher',
#        'High school graduate or higher - Margin of error',
#        'High school graduate or higher - Share',
#        'High school graduate or higher - Share - Margin of error',
#        'Bachelor's degree or higher',
#        'Bachelor's degree or higher - Margin of error'],
#       dtype='object')

# %%
df.columns[400:500]
# Out:
# Index(['Bachelor's degree or higher - Share',
#        'Bachelor's degree or higher - Share - Margin of error',
#        'Workers (16 years and older)',
#        'Workers (16 years and older) - Margin of error',
#        'Workers (16 years and older) - Share',
#        'Workers (16 years and older) - Share - Margin of error',
#        'Workers (16 years and older; not home based)',
#        'Workers (16 years and older; not home based) - Margin of error',
#        'Workers (16 years and older; not home based) - Share',
#        'Workers (16 years and older; not home based) - Share - Margin of error',
#        'Car; truck; or van (including passengers)',
#        'Car; truck; or van (including passengers) - Margin of error',
#        'Car; truck; or van (including passengers) - Share',
#        'Car; truck; or van (including passengers) - Share - Margin of error',
#        'Public transportation', 'Public transportation - Margin of error',
#        'Public transportation - Share',
#        'Public transportation - Share - Margin of error',
#        'Walked; biked; worked at home; or other',
#        'Walked; biked; worked at home; or other - Margin of error',
#        'Walked; biked; worked at home; or other - Share',
#        'Walked; biked; worked at home; or other - Share - Margin of error',
#        'Less than 10 minutes', 'Less than 10 minutes - Margin of error',
#        'Less than 10 minutes - Share',
#        'Less than 10 minutes - Share - Margin of error', '10-19 minutes',
#        '10-19 minutes - Margin of error', '10-19 minutes - Share',
#        '10-19 minutes - Share - Margin of error', '20-29 minutes',
#        '20-29 minutes - Margin of error', '20-29 minutes - Share',
#        '20-29 minutes - Share - Margin of error', '30 minutes or longer',
#        '30 minutes or longer - Margin of error',
#        '30 minutes or longer - Share',
#        '30 minutes or longer - Share - Margin of error',
#        'Population without health insurance coverage',
#        'Population without health insurance coverage - Margin of error',
#        'Population without health insurance coverage - Share',
#        'Population without health insurance coverage - Share - Margin of error',
#        '17 years and younger (percent of people under age 18)',
#        '17 years and younger (percent of people under age 18) - Margin of error',
#        '17 years and younger (percent of people under age 18) - Share',
#        '17 years and younger (percent of people under age 18) - Share - Margin of error',
#        '18-64 (percent of people 18-64)',
#        '18-64 (percent of people 18-64) - Margin of error',
#        '18-64 (percent of people 18-64) - Share',
#        '18-64 (percent of people 18-64) - Share - Margin of error',
#        '65 years and older (percent of people age 65+)',
#        '65 years and older (percent of people age 65+) - Margin of error',
#        '65 years and older (percent of people age 65+) - Share',
#        '65 years and older (percent of people age 65+) - Share - Margin of error',
#        '18-24 (percent of people age 18-24)',
#        '18-24 (percent of people age 18-24) - Margin of error',
#        '18-24 (percent of people age 18-24) - Share',
#        '18-24 (percent of people age 18-24) - Share - Margin of error',
#        '25-34 (percent of people age 25-34)',
#        '25-34 (percent of people age 25-34) - Margin of error',
#        '25-34 (percent of people age 25-34) - Share',
#        '25-34 (percent of people age 25-34) - Share - Margin of error',
#        '35-44 (percent of people age 35-44)',
#        '35-44 (percent of people age 35-44) - Margin of error',
#        '35-44 (percent of people age 35-44) - Share',
#        '35-44 (percent of people age 35-44) - Share - Margin of error',
#        '45-54 (percent of people age 45-54)',
#        '45-54 (percent of people age 45-54) - Margin of error',
#        '45-54 (percent of people age 45-54) - Share',
#        '45-54 (percent of people age 45-54) - Share - Margin of error',
#        '55-64 (percent of people age 55-64)',
#        '55-64 (percent of people age 55-64) - Margin of error',
#        '55-64 (percent of people age 55-64) - Share',
#        '55-64 (percent of people age 55-64) - Share - Margin of error',
#        'Total Employed Workers', 'Total Employed Workers - Share',
#        'Worker Age 29 or younger', 'Worker Age 29 or younger - Share',
#        'Worker Age 30 to 54', 'Worker Age 30 to 54 - Share',
#        'Worker Age 55 or older', 'Worker Age 55 or older - Share',
#        'Workers $15000 per year or less',
#        'Workers $15000 per year or less - Share',
#        'Workers $15001 to $39999 per year',
#        'Workers $15001 to $39999 per year - Share',
#        'Workers $40000 or more per year',
#        'Workers $40000 or more per year - Share',
#        'Agriculture; forestry; fishing and hunting',
#        'Agriculture; forestry; fishing and hunting - Share',
#        'Mining; quarrying; and oil and gas extraction',
#        'Mining; quarrying; and oil and gas extraction - Share', 'Utilities',
#        'Utilities - Share', 'Construction', 'Construction - Share',
#        'Manufacturing', 'Manufacturing - Share', 'Wholesale trade',
#        'Wholesale trade - Share'],
#       dtype='object')
